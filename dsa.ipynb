# %% [markdown]
# <a href="https://colab.research.google.com/github/denizbariscan/DSA210-Term-Project/blob/data/dsa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/dsa/Hilltown Ürün Çıkış Raporu 8 Ekim - 10 Nisan.xlsx'
hilltown_df = pd.read_excel(file_path)
top15hilltownrevenue = hilltown_df.sort_values(by='Tutar', ascending=False).head(15)

plt.figure(figsize=(12, 6))
sns.barplot(data=top15hilltownrevenue, x='Tutar', y='Ürün Adı', palette='crest')
plt.title("Hilltown Branch – Top 15 Products by Revenue")
plt.xlabel("Total Revenue (₺)")
plt.ylabel("Product Name")
plt.grid(True, axis='x')
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-51-4c210dbd97c5>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top15hilltownrevenue, x='Tutar', y='Ürün Adı', palette='crest')

# %%
file_path_balcova = '/content/drive/MyDrive/dsa/urun-cikis-raporu-1744210116 (1).xlsx'
balcova_df = pd.read_excel(file_path_balcova)
top15balcovarevenue = balcova_df.sort_values(by='Tutar', ascending=False).head(15)

plt.figure(figsize=(12, 6))
sns.barplot(data=top15balcovarevenue, x='Tutar', y='Ürün Adı', palette='Blues')
plt.title("Balçova Branch – Top 15 Products by Revenue")
plt.xlabel("Total Revenue (₺)")
plt.ylabel("Product Name")
plt.grid(True, axis='x')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-48-36cb727670fc>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top15_balcova_revenue, x='Tutar', y='Ürün Adı', palette='Blues')

# %%
monthlyrevenueht = {
    "Ekim": 3_237_584.80,
    "Kasım": 3_228_013.60,
    "Aralık": 3_296_657.73,
    "Ocak": 3_495_294.48,
    "Şubat": 2_725_767.42,
    "Mart": 3_211_515.63,
    "Nisan": 3_211_515.63
}
days_in_month = {
    "Ekim": 31,
    "Kasım": 30,
    "Aralık": 31,
    "Ocak": 31,
    "Şubat": 28,
    "Mart": 31,
    "Nisan": 24
}
months_en = {
    "Ekim": "October",
    "Kasım": "November",
    "Aralık": "December",
    "Ocak": "January",
    "Şubat": "February",
    "Mart": "March",
    "Nisan": "April"
}
months_ordered = ["October", "November", "December", "January", "February", "March", "April"]
months_tr_ordered = [month_tr for month_tr, month_en in months_en.items() if month_en in months_ordered]
htdaily_df = pd.DataFrame({
    "Month": months_ordered,  # Use English month names directly
    "Daily Revenue": [monthlyrevenueht[month_tr] / days_in_month[month_tr] for month_tr in months_tr_ordered]
})
plt.figure(figsize=(10, 5))
plt.plot(htdaily_df["Month"], htdaily_df["Daily Revenue"], marker='o', color='darkblue')
plt.title("Hilltown Branch - Average Daily Revenue by Month")
plt.xlabel("Month")
plt.ylabel("Daily Revenue (₺)")
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
monthly_revenue_balçova = {
    "Ekim": 848_267.60,
    "Kasım": 1_258_737.80,
    "Aralık": 1_565_782.00,
    "Ocak": 1_831_322.35,
    "Şubat": 1_675_118.05,
    "Mart": 2_157_938.25,
    "Nisan": 1_918_506.87
}
days_in_month = {
    "Ekim": 31,
    "Kasım": 30,
    "Aralık": 31,
    "Ocak": 31,
    "Şubat": 28,
    "Mart": 31,
    "Nisan": 22
}
months_en = {
    "Ekim": "October",
    "Kasım": "November",
    "Aralık": "December",
    "Ocak": "January",
    "Şubat": "February",
    "Mart": "March",
    "Nisan": "April"
}
months_ordered = ["Ekim", "Kasım", "Aralık", "Ocak", "Şubat", "Mart", "Nisan"]
balçova_daily_df = pd.DataFrame({
    "Month": [months_en[month] for month in months_ordered],
    "Daily Revenue": [monthly_revenue_balçova[month] / days_in_month[month] for month in months_ordered]
})
plt.figure(figsize=(10, 5))
plt.plot(balçova_daily_df["Month"], balçova_daily_df["Daily Revenue"], marker='o', color='darkred')
plt.title("Balçova Branch - Average Daily Revenue by Month")
plt.xlabel("Month")
plt.ylabel("Daily Revenue (₺)")
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
monthly_revenue_balçova = {
    "Ekim": 848_267.60,
    "Kasım": 1_258_737.80,
    "Aralık": 1_565_782.00,
    "Ocak": 1_831_322.35,
    "Şubat": 1_675_118.05,
    "Mart": 2_157_938.25,
    "Nisan": 1_918_506.87
}
monthly_revenue_hilltown = {
    "Ekim": 3_237_584.80,
    "Kasım": 3_228_013.60,
    "Aralık": 3_296_657.73,
    "Ocak": 3_495_294.48,
    "Şubat": 2_725_767.42,
    "Mart": 3_211_515.63,
    "Nisan": 3_211_515.63
}
days_in_month = {
    "Ekim": 31,
    "Kasım": 30,
    "Aralık": 31,
    "Ocak": 31,
    "Şubat": 28,
    "Mart": 31,
    "Nisan": 24
}
months_en = {
    "Ekim": "October",
    "Kasım": "November",
    "Aralık": "December",
    "Ocak": "January",
    "Şubat": "February",
    "Mart": "March",
    "Nisan": "April"
}
months_ordered = ["Ekim", "Kasım", "Aralık", "Ocak", "Şubat", "Mart", "Nisan"]
hilltown_daily_df = pd.DataFrame({
    "Month": [months_en[month] for month in months_ordered],
    "Daily Revenue": [monthly_revenue_hilltown[month] / days_in_month[month] for month in months_ordered]
})
balçova_daily_df = pd.DataFrame({
    "Month": [months_en[month] for month in months_ordered],
    "Daily Revenue": [monthly_revenue_balçova[month] / days_in_month[month] for month in months_ordered]
})
plt.figure(figsize=(12, 6))
plt.plot(hilltown_daily_df["Month"], hilltown_daily_df["Daily Revenue"], marker='o', label="Hilltown", color='navy')
plt.plot(balçova_daily_df["Month"], balçova_daily_df["Daily Revenue"], marker='o', label="Balçova", color='darkred')
plt.title("Average Daily Revenue Comparison: Balçova vs Hilltown Branches")
plt.xlabel("Month")
plt.ylabel("Daily Revenue (₺)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
weatherdata = {
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "Avg Temperature (°C)": [17.9, 12.8, 8.1, 6.7, 8.0, 10.8, 14.8],
    "Total Precipitation (mm)": [65, 100, 116, 112, 105, 84, 67],
    "Rainy Days": [4, 6, 9, 8, 8, 7, 6]
}

df_weather = pd.DataFrame(weatherdata)
fig, ax1 = plt.subplots(figsize=(10, 5))
color = 'red'
ax1.set_xlabel("Month")
ax1.set_ylabel("Avg Temperature (°C)", color=color)
ax1.plot(df_weather["Month"], df_weather["Avg Temperature (°C)"], marker='o', color=color, label="Avg Temp")
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(df_weather["Month"], rotation=45)

ax2 = ax1.twinx()
color = 'steelblue'
ax2.set_ylabel("Rainy Days", color=color)
ax2.bar(df_weather["Month"], df_weather["Rainy Days"], alpha=0.5, color=color, label="Rainy Days")
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Average Temperature and Rainy Days in İzmir (Oct 2024 - Apr 2025)")
fig.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.show()
# Out:
# <ipython-input-60-f5f46784a672>:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df_weather["Month"], rotation=45)

# %%
holiday = {
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "School Vacation Days (High Schools)": [1.5, 5, 0, 11, 0, 1, 4]
}
df_holidays = pd.DataFrame(holiday)
plt.figure(figsize=(10, 5))
plt.plot(df_holidays["Month"], df_holidays["School Vacation Days (High Schools)"], marker='o', color='darkgreen')
plt.title("Monthly Additional School Vacation Days (High Schools)")
plt.xlabel("Month")
plt.ylabel("Additional Vacation Days")
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
from scipy.stats import pearsonr

df_weather = pd.DataFrame({
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "Avg Temperature (°C)": [17.9, 12.8, 8.1, 6.7, 8.0, 10.8, 14.8]
})
htdaily_df = pd.DataFrame({
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "Average Daily Revenue": [104438.22, 107600.45, 106343.80,
                      112751.43, 93991.98, 103597.92, 133813.15]
})
merged_df = pd.merge(df_weather, htdaily_df, on="Month")

correlation, p_value = pearsonr(merged_df["Avg Temperature (°C)"], merged_df["Average Daily Revenue"])

plt.figure(figsize=(8, 5))
sns.regplot(x="Avg Temperature (°C)", y="Average Daily Revenue", data=merged_df, color="royalblue")
plt.title(f"Correlation Between Avg Temperature and Hilltown Daily Revenue\nPearson r = {correlation:.2f}", fontsize=13)
plt.xlabel("Average Monthly Temperature (°C)")
plt.ylabel("Hilltown Daily Revenue (₺)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_holidays = pd.DataFrame({
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "School Vacation Days (High Schools)": [1.5, 5, 0, 11, 0, 1, 4]
})
htdaily_df = pd.DataFrame({
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "Average Daily Revenue": [104438.22, 107600.45, 106343.80,
                      112751.43, 93991.98, 103597.92, 133813.15]
})
merged_holiday_df = pd.merge(df_holidays, htdaily_df, on="Month")
merged_holiday_df.rename(columns={"School Vacation Days (High Schools)": "Vacation Days"}, inplace=True)
correlation_holiday, p_value_holiday = pearsonr(merged_holiday_df["Vacation Days"], merged_holiday_df["Average Daily Revenue"])

plt.figure(figsize=(8, 5))
sns.regplot(x="Vacation Days", y="Average Daily Revenue", data=merged_holiday_df, color="darkorange")
plt.title(f"Correlation Between School Break Days and Hilltown Daily Revenue\nPearson r = {correlation_holiday:.2f}", fontsize=13)
plt.xlabel("Monthly School Vacation Days")
plt.ylabel("Hilltown Daily Revenue (₺)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_weather = pd.DataFrame({
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "Avg Temperature (°C)": [17.9, 12.8, 8.1, 6.7, 8.0, 10.8, 14.8]
})

balçovadaily_df = pd.DataFrame({
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "Daily Revenue": [27363.47, 41957.93, 50509.10,
                      59074.91, 57762.69, 69546.39, 79937.79]
})

merged_balçova_temp_df = pd.merge(df_weather, balçovadaily_df, on="Month")

corr_temp_balçova, _ = pearsonr(merged_balçova_temp_df["Avg Temperature (°C)"], merged_balçova_temp_df["Daily Revenue"])

plt.figure(figsize=(8, 5))
sns.regplot(x="Avg Temperature (°C)", y="Daily Revenue", data=merged_balçova_temp_df, color="crimson")
plt.title(f"Correlation Between Avg Temperature and Balçova Daily Revenue\nPearson r = {corr_temp_balçova:.2f}", fontsize=13)
plt.xlabel("Average Monthly Temperature (°C)")
plt.ylabel("Balçova Daily Revenue (₺)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_holidays = pd.DataFrame({
    "Month": ["October 2024", "November 2024", "December 2024",
              "January 2025", "February 2025", "March 2025", "April 2025"],
    "School Break Days (High Schools)": [1.5, 5, 0, 11, 0, 1, 4]
})

merged_balçova_holiday_df = pd.merge(df_holidays, balçova_daily_df, on="Month")
merged_balçova_holiday_df.rename(columns={"School Break Days (High Schools)": "Break Days"}, inplace=True)


corr_holiday_balçova, _ = pearsonr(merged_balçova_holiday_df["Break Days"], merged_balçova_holiday_df["Daily Revenue"])

plt.figure(figsize=(8, 5))
sns.regplot(x="Break Days", y="Daily Revenue", data=merged_balçova_holiday_df, color="darkgreen")
plt.title(f"Correlation Between School Break Days and Balçova Daily Revenue\nPearson r = {corr_holiday_balçova:.2f}", fontsize=13)
plt.xlabel("Monthly School Break Days")
plt.ylabel("Balçova Daily Revenue (₺)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
months_ordered = ["October 2024", "November 2024", "December 2024",
                  "January 2025", "February 2025", "March 2025", "April 2025"]

balçova_cirolar = [27363.47, 41957.93, 50509.10, 59074.91, 57762.69, 69546.39, 79937.79]

dates = pd.date_range(start="2024-10-01", periods=7, freq="MS")
df_line = pd.DataFrame({
    "Date": dates,
    "Daily Revenue": balçova_cirolar
})
plt.figure(figsize=(10, 5))
plt.plot(df_line["Date"], df_line["Daily Revenue"], marker='o', color='crimson', label="Balçova Daily Revenue")
plt.title("Balçova Branch - Daily Revenue Trend (Oct 2024 – Apr 2025)", fontsize=13)
plt.xlabel("Month")
plt.ylabel("Daily Revenue (₺)")
plt.grid(True)
plt.axvspan(pd.to_datetime("2025-01-12"), pd.to_datetime("2025-02-10"),
            color='lightgrey', alpha=0.4, label="IUE Winter Break")

plt.legend()
plt.tight_layout()
plt.show()

# %%
dates = pd.date_range(start="2024-10-01", periods=7, freq="MS")
hilltown_cirolar = [104438.22, 107600.45, 106343.80, 112751.43, 93991.98, 103597.92, 133813.15]

df_hilltown_line = pd.DataFrame({
    "Date": dates,
    "Daily Revenue": hilltown_cirolar
})

plt.figure(figsize=(10, 5))
plt.plot(df_hilltown_line["Date"], df_hilltown_line["Daily Revenue"], marker='o', color='navy', label="Hilltown Daily Revenue")
plt.title("Hilltown Branch - Daily Revenue Trend (Oct 2024 – Apr 2025)", fontsize=13)
plt.xlabel("Month")
plt.ylabel("Daily Revenue (₺)")
plt.grid(True)
plt.axvspan(pd.to_datetime("2025-01-20"), pd.to_datetime("2025-01-31"),
            color='lightgrey', alpha=0.4, label="High School Winter Break")

plt.legend()
plt.tight_layout()
plt.show()

# %%
weather_rain = {
    "Month": [
        "October 2024", "November 2024", "December 2024",
        "January 2025", "February 2025", "March 2025", "April 2025"
    ],
    "Rainy Days": [4, 6, 9, 8, 8, 7, 6],
    "Hilltown Daily Revenue": htdaily_df["Average Daily Revenue"].tolist(),
    "Balcova Daily Revenue": balçova_daily_df["Daily Revenue"].tolist()  # Changed balçovadaily_df to balçova_daily_df
}

df = pd.DataFrame(weather_rain)
r_hilltown, _ = pearsonr(df["Rainy Days"], df["Hilltown Daily Revenue"])
r_balcova, _ = pearsonr(df["Rainy Days"], df["Balcova Daily Revenue"])

z_hilltown = 0.5 * np.log((1 + r_hilltown) / (1 - r_hilltown))
z_balcova = 0.5 * np.log((1 + r_balcova) / (1 - r_balcova))

n1 = n2 = 7
z_score = (z_hilltown - z_balcova) / np.sqrt(1/(n1 - 3) + 1/(n2 - 3))
print(f"Pearson r (Hilltown) = {r_hilltown:.2f}")
print(f"Pearson r (Balcova)  = {r_balcova:.2f}")
print(f"Fisher Z-score = {z_score:.2f}")
if abs(z_score) > 1.96:
    print("Reject H₀: Rainy weather effects on sales differ significantly between branches.")
else:
    print("Fail to Reject H₀: Rainy weather effects on sales do not differ significantly between branches.")
# Out:
# Pearson r (Hilltown) = -0.21
# Pearson r (Balcova)  = 0.41
# Fisher Z-score = -0.92
# Fail to Reject H₀: Rainy weather effects on sales do not differ significantly between branches.

# %%
file_path = '/content/drive/MyDrive/dsa/ortak ürünler farklar.xlsx'
df = pd.read_excel(file_path)
df_clean = df.dropna(subset=['Fiyat Farkı (Hilltown - Balçova)', 'Satış Farkı (Hilltown - Balçova)'])

price_diff = df_clean['Fiyat Farkı (Hilltown - Balçova)']
sales_diff = df_clean['Satış Farkı (Hilltown - Balçova)']

correlation, p_value = pearsonr(price_diff, sales_diff)

print("Pearson Correlation Test Results")
print("-----------------------------------")
print(f"Correlation coefficient: {correlation:.4f}")
print(f"p-value: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Reject H₀: There is a significant relationship between the price difference and sales quantity between the two branches.")
else:
    print("Fail to Reject H₀: There is no significant relationship between the price difference and sales quantity between the two branches.")
plt.figure(figsize=(8,6))
plt.scatter(price_diff, sales_diff, alpha=0.7, edgecolors='k')
plt.title(f'Price vs. Sales Difference\nCorrelation: {correlation:.2f}, p-value: {p_value:.3f}')
plt.xlabel('Price Difference (Hilltown - Balçova)')
plt.ylabel('Sales Difference (Hilltown - Balçova)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson Correlation Test Results
# -----------------------------------
# Correlation coefficient: -0.1218
# p-value: 0.2273
# Fail to Reject H₀: There is no significant relationship between the price difference and sales quantity between the two branches.

# %%
from scipy.stats import chi2_contingency
df = pd.read_excel("/content/drive/MyDrive/dsa/ortak ürünler farklar.xlsx")

def sales_outcome(diff):
    if diff > 0:
        return "Mall advantaged"
    elif diff < 0:
        return "University advantaged"
    else:
        return "Equal"

df['Sales Outcome'] = df['Satış Farkı (Hilltown - Balçova)'].apply(sales_outcome)
df['Winning Location'] = df['Sales Outcome'].map({
    "Mall advantaged": "Mall",
    "University advantaged": "University",
    "Equal": "Equal"
})
contingency_table = pd.crosstab(df['Winning Location'], df['Sales Outcome'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print("Contingency Table:")
print(contingency_table)
print("\nChi-Square value:", chi2)
print("p-value:", p_value)
if p_value < 0.05:
    print("Reject H₀: There is a significant relationship between the location type (mall vs. university area) and the sales advantage.")
else:
    print("Fail to Reject H₀: There is no significant relationship between the location type and the sales advantage.")
# Out:
# Contingency Table:
# Sales Outcome     Equal  Mall advantaged  University advantaged
# Winning Location
# Equal                34                0                      0
# Mall                  0               61                      0
# University            0                0                     38
#
# Chi-Square value: 265.99999999999994
# p-value: 2.3224089967377557e-56
# H0 rejected: There is a significant relationship between the location type (mall vs. university area) and the sales advantage.
